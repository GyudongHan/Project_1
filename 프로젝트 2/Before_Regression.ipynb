# %% [markdown]
# # 한글설치

# %%
from matplotlib import rc, font_manager as fm

# 나눔고딕 폰트 경로 설정
font_path = '../나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_path).get_name()

# 폰트 설정
rc('font', family=font_name)

# %%
import pandas as pd

# %%
df = pd.read_csv('data/구별_쓰레기_예측용.csv')
df
# Out:
#      자치구  PET 총량  PET 량(공공처리)  PET 량(위탁)  CAN 총량  CAN 량(공공처리)  CAN 량(위탁)  \
# 0    종로구   738.6        219.3      519.3   443.5        138.9      304.6
# 1     중구   712.8        565.9      146.9   484.4        373.3      111.1
# 2    용산구   973.0        764.8      208.2   469.9        301.8      168.1
# 3    성동구  1671.3       1149.5      521.8   931.7        454.6      477.1
# 4    광진구  1315.5          0.0     1315.5   552.8          0.0      552.8
# 5   동대문구  1632.7        594.8     1037.9   778.3        239.8      538.5
# 6    중랑구  1924.0       1458.9      465.1   705.4        368.3      337.1
# 7    성북구   951.8          0.0      951.8   585.4          0.0      585.4
# 8    강북구  1147.1          0.0     1147.1   193.6          0.0      193.6
# 9    도봉구   771.8          0.0      771.8   353.5          0.0      353.5
# 10   노원구  1587.0          0.0     1587.0   958.1          0.0      958.1
# 11   은평구  1970.2        937.9     1032.3   654.9        422.0      232.9
# ...

# %%
"""
import seaborn as sns
import matplotlib.pyplot as plt

# 주어진 데이터프레임(df)에서 필요한 열만 추출
df_subset = df[['PET 총량', 'CAN 총량', '구별_총생활인구수_평균', '구별_연령대0_생활인구_평균', '구별_연령대10_생활인구_평균',
       '구별_연령대20_생활인구_평균', '구별_연령대30_생활인구_평균', '구별_연령대40_생활인구_평균',
       '구별_연령대50_생활인구_평균', '구별_연령대60_생활인구_평균', '구별_연령대70_생활인구_평균', '1인가구',
       '2인가구', '3인가구', '4인가구', '5인가구', '6인가구', '7인 이상 가구', '유흥주점영업', '단란주점',
       '제과점영업', '집단급식소', '일반음식점', '휴게음식점', '연령대_100_거주인구수', '구별_연령대0_거주인구_평균',
       '구별_연령대10_거주인구_평균', '구별_연령대20_거주인구_평균', '구별_연령대30_거주인구_평균',
       '구별_연령대40_거주인구_평균', '구별_연령대50_거주인구_평균', '구별_연령대60_거주인구_평균',
       '구별_연령대70_거주인구_평균', '구별_연령대80_거주인구_평균', '구별_연령대90_거주인구_평균']]


# 상관행렬 계산
correlation_matrix = df_subset.corr()

# Heatmap 그리기
plt.figure(figsize=(50, 30))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("상관분석 Heatmap")
plt.show()
"""
# Out:
# '\nimport seaborn as sns\nimport matplotlib.pyplot as plt\n\n# 주어진 데이터프레임(df)에서 필요한 열만 추출\ndf_subset = df[[\'PET 총량\', \'CAN 총량\', \'구별_총생활인구수_평균\', \'구별_연령대0_생활인구_평균\', \'구별_연령대10_생활인구_평균\',\n       \'구별_연령대20_생활인구_평균\', \'구별_연령대30_생활인구_평균\', \'구별_연령대40_생활인구_평균\',\n       \'구별_연령대50_생활인구_평균\', \'구별_연령대60_생활인구_평균\', \'구별_연령대70_생활인구_평균\', \'1인가구\',\n       \'2인가구\', \'3인가구\', \'4인가구\', \'5인가구\', \'6인가구\', \'7인 이상 가구\', \'유흥주점영업\', \'단란주점\',\n       \'제과점영업\', \'집단급식소\', \'일반음식점\', \'휴게음식점\', \'연령대_100_거주인구수\', \'구별_연령대0_거주인구_평균\',\n       \'구별_연령대10_거주인구_평균\', \'구별_연령대20_거주인구_평균\', \'구별_연령대30_거주인구_평균\',\n       \'구별_연령대40_거주인구_평균\', \'구별_연령대50_거주인구_평균\', \'구별_연령대60_거주인구_평균\',\n       \'구별_연령대70_거주인구_평균\', \'구별_연령대80_거주인구_평균\', \'구별_연령대90_거주인구_평균\']]\n\n\n# 상관행렬 계산\ncorrelation_matrix = df_subset.corr()\n\n# Heatmap 그리기\nplt.figure(figsize=(50, 30))\nsns.heatmap(correlation_matrix, annot=True, cmap=\'coolwarm\', fmt=".2f")\nplt.title("상관분석 Heatmap")\nplt.show()\n'

# %%
df.columns
# Out:
# Index(['자치구', 'PET 총량', 'PET 량(공공처리)', 'PET 량(위탁)', 'CAN 총량', 'CAN 량(공공처리)',
#        'CAN 량(위탁)', '구별_총생활인구수_평균', '구별_연령대0_생활인구_평균', '구별_연령대10_생활인구_평균',
#        '구별_연령대20_생활인구_평균', '구별_연령대30_생활인구_평균', '구별_연령대40_생활인구_평균',
#        '구별_연령대50_생활인구_평균', '구별_연령대60_생활인구_평균', '구별_연령대70_생활인구_평균', '1인가구',
#        '2인가구', '3인가구', '4인가구', '5인가구', '6인가구', '7인 이상 가구', '유흥주점영업', '단란주점',
#        '제과점영업', '집단급식소', '일반음식점', '휴게음식점', '연령대_100_거주인구수', '구별_연령대0_거주인구_평균',
#        '구별_연령대10_거주인구_평균', '구별_연령대20_거주인구_평균', '구별_연령대30_거주인구_평균',
#        '구별_연령대40_거주인구_평균', '구별_연령대50_거주인구_평균', '구별_연령대60_거주인구_평균',
#        '구별_연령대70_거주인구_평균', '구별_연령대80_거주인구_평균', '구별_연령대90_거주인구_평균'],
#       dtype='object')
