# %%
import pandas as pd
# !pip install openpyxl

# 데이터 불러오기
df1 = pd.read_csv('data/bus_2022.csv')   # 서울시 버스노선별 정류장별 시간대별 승하차 인원 정보 2022년
df2 = pd.read_excel('data/seoul_bus_wgs84(2022.11.30).xlsx')   # 서울시 버스정류소 위치정보(2022.11.30)
# Out:
# ...
# C:\Users\user\AppData\Local\Temp\ipykernel_16360\4217399081.py:5: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('data/bus_2022.csv')   # 서울시 버스노선별 정류장별 시간대별 승하차 인원 정보 2022년

# %%
# 데이터 확인
print(df1, df2)
# Out:
#         USE_MON BUS_ROUTE_NO     BUS_ROUTE_NM  STND_BSST_ID BSST_ARS_NO  \
# 0        202201          100   100번(하계동~용산구청)     110000327       11428
# 1        202201          100   100번(하계동~용산구청)     110000335       11436
# 2        202201          100   100번(하계동~용산구청)     107000011       08101
# 3        202201          100   100번(하계동~용산구청)     107000012       08102
# 4        202201          100   100번(하계동~용산구청)     107000013       08103
# ...         ...          ...              ...           ...         ...
# 482981   202212         9714  9714번(교하운정~서울역)     229001663       63737
# 482982   202212         9714  9714번(교하운정~서울역)     229000848       63659
# 482983   202212         9714  9714번(교하운정~서울역)     229000847       63674
# 482984   202212         9714  9714번(교하운정~서울역)     229001300       30839
# 482985   202212         9714  9714번(교하운정~서울역)     229002499       30745
#
#               BUS_STA_NM  MIDNIGHT_RIDE_NUM  MIDNIGHT_ALIGHT_NUM  \
# ...

# %%
# 일단 이 데이터의 컬럼과 각 데이터들이 뭘나타내느질 파악
df2.head(6)
# Out:
#      NODE_ID  ARS-ID           정류소명         X좌표        Y좌표
# 0  100000001    1001        종로2가사거리  126.987750  37.569765
# 1  100000002    1002    창경궁.서울대학교병원  126.996566  37.579183
# 2  100000003    1003      명륜3가.성대입구  126.998340  37.582671
# 3  100000004    1004       종로2가.삼일교  126.987613  37.568579
# 4  100000005    1005  혜화동로터리.여운형활동터  127.001744  37.586243
# 5  101000305    1006        서대문역사거리  126.966893  37.566137

# %%
# 무조건 주소가 강남구인 정류소는 뭘까?
df2[df2['정류소명'].str.contains('강남구청')]
# Out:
#         NODE_ID  ARS-ID        정류소명         X좌표        Y좌표
# 9825  122000027   23127       강남구청역  127.040641  37.518466
# 9826  122000028   23128       강남구청역  127.040047  37.516982
# 9833  122000035   23135       강남구청역  127.040262  37.516656
# 9874  122000074   23176  강남구청.강남세무서  127.047157  37.518493
# 9876  122000076   23178       강남구청역  127.041014  37.518301
# 9904  122000103   23206  강남구청.강남세무서  127.047774  37.518201

# %%
# 23* 인 정류소 ID를 탐색
df2[df2['ARS-ID'].astype(str).str.startswith('23')]
# Out:
#          NODE_ID  ARS-ID             정류소명         X좌표        Y좌표
# 9799   122000001   23101            신사중학교  127.020499  37.522928
# 9800   122000002   23102            신사중학교  127.021022  37.523564
# 9801   122000003   23103      광림교회.현대고등학교  127.025266  37.525387
# 9802   122000004   23104      광림교회.현대고등학교  127.024439  37.525278
# 9803   122000005   23105         압구정역4번출구  127.028258  37.526154
# ...          ...     ...              ...         ...        ...
# 10350  122000706   23989         영동대교(가상)  127.055620  37.526625
# 10351  122000672   23992       성수대교남단(가상)  127.030882  37.533628
# 10352  122900073   23993     강남신동아파밀리에2단지  127.101453  37.464585
# 10353  122000287   23994   일원주유소.삼성서울병원후문  127.087682  37.490654
# 10354  122900074   23995  리엔파크4단지.강남데시앙파크  127.101976  37.461272
#
# [556 rows x 5 columns]

# %%
# 강남구 정류장 코드만 새로운 DF로 Gangnam_BUS_ID
GBI = df2[df2['ARS-ID'].astype(str).str.startswith('23')].reset_index(drop=True)
GBI
# Out:
#        NODE_ID  ARS-ID             정류소명         X좌표        Y좌표
# 0    122000001   23101            신사중학교  127.020499  37.522928
# 1    122000002   23102            신사중학교  127.021022  37.523564
# 2    122000003   23103      광림교회.현대고등학교  127.025266  37.525387
# 3    122000004   23104      광림교회.현대고등학교  127.024439  37.525278
# 4    122000005   23105         압구정역4번출구  127.028258  37.526154
# ..         ...     ...              ...         ...        ...
# 551  122000706   23989         영동대교(가상)  127.055620  37.526625
# 552  122000672   23992       성수대교남단(가상)  127.030882  37.533628
# 553  122900073   23993     강남신동아파밀리에2단지  127.101453  37.464585
# 554  122000287   23994   일원주유소.삼성서울병원후문  127.087682  37.490654
# 555  122900074   23995  리엔파크4단지.강남데시앙파크  127.101976  37.461272
#
# [556 rows x 5 columns]

# %%
# 서울시 버스노선별 정류장별 시간대별 승하차 인원 정보 2022년
df1
# Out:
#         USE_MON BUS_ROUTE_NO     BUS_ROUTE_NM  STND_BSST_ID BSST_ARS_NO  \
# 0        202201          100   100번(하계동~용산구청)     110000327       11428
# 1        202201          100   100번(하계동~용산구청)     110000335       11436
# 2        202201          100   100번(하계동~용산구청)     107000011       08101
# 3        202201          100   100번(하계동~용산구청)     107000012       08102
# 4        202201          100   100번(하계동~용산구청)     107000013       08103
# ...         ...          ...              ...           ...         ...
# 482981   202212         9714  9714번(교하운정~서울역)     229001663       63737
# 482982   202212         9714  9714번(교하운정~서울역)     229000848       63659
# 482983   202212         9714  9714번(교하운정~서울역)     229000847       63674
# 482984   202212         9714  9714번(교하운정~서울역)     229001300       30839
# 482985   202212         9714  9714번(교하운정~서울역)     229002499       30745
#
#               BUS_STA_NM  MIDNIGHT_RIDE_NUM  MIDNIGHT_ALIGHT_NUM  \
# ...

# %%
# 이 데이터에서도 같은 버스정류장 ID 고유값이 일치하는지 먼저 확인
df1[df1['BSST_ARS_NO'].astype(str).str.startswith('23')].sort_values(by='BSST_ARS_NO')
# Out:
#         USE_MON BUS_ROUTE_NO           BUS_ROUTE_NM  STND_BSST_ID BSST_ARS_NO  \
# 72549    202202         1156  1156번(퇴계원쌍용예가아파트~석계역)     222000296       23045
# 353727   202209         1156  1156번(퇴계원쌍용예가아파트~석계역)     222000296       23045
# 151833   202204         1156  1156번(퇴계원쌍용예가아파트~석계역)     222000296       23045
# 476852   202212         1156  1156번(퇴계원쌍용예가아파트~석계역)     222000296       23045
# 435353   202211         1156  1156번(퇴계원쌍용예가아파트~석계역)     222000296       23045
# ...         ...          ...                    ...           ...         ...
# 265087   202207       강남06-2     강남06-2(세곡리엔파크~수서역)     122900074       23995
# 427178   202211       강남06-1     강남06-1(세곡리엔파크~수서역)     122900074       23995
# 224833   202206       강남06-2     강남06-2(세곡리엔파크~수서역)     122900074       23995
# 25954    202201       강남06-2     강남06-2(세곡리엔파크~수서역)     122900074       23995
# 64584    202202       강남06-1     강남06-1(세곡리엔파크~수서역)     122900074       23995
#
# ...

# %%
# 퇴계원이 뭐지?? 남양주시 정보도 같이 있는 거였음. 이제보니 정확하게는 231* 부터 강남구! 
# 필요없는 데이터 삭제.
df1 = df1[~df1['BSST_ARS_NO'].astype(str).str.startswith('230')]
df1
# Out:
#         USE_MON BUS_ROUTE_NO     BUS_ROUTE_NM  STND_BSST_ID BSST_ARS_NO  \
# 0        202201          100   100번(하계동~용산구청)     110000327       11428
# 1        202201          100   100번(하계동~용산구청)     110000335       11436
# 2        202201          100   100번(하계동~용산구청)     107000011       08101
# 3        202201          100   100번(하계동~용산구청)     107000012       08102
# 4        202201          100   100번(하계동~용산구청)     107000013       08103
# ...         ...          ...              ...           ...         ...
# 482981   202212         9714  9714번(교하운정~서울역)     229001663       63737
# 482982   202212         9714  9714번(교하운정~서울역)     229000848       63659
# 482983   202212         9714  9714번(교하운정~서울역)     229000847       63674
# 482984   202212         9714  9714번(교하운정~서울역)     229001300       30839
# 482985   202212         9714  9714번(교하운정~서울역)     229002499       30745
#
#               BUS_STA_NM  MIDNIGHT_RIDE_NUM  MIDNIGHT_ALIGHT_NUM  \
# ...

# %%
# 강남구 버스 승하차 데이터만 새로운 DF로 Gangnam_BUS_Data
GBD=df1[df1['BSST_ARS_NO'].astype(str).str.startswith('23')].sort_values(by='BSST_ARS_NO').reset_index(drop=True)
GBD
# Out:
#        USE_MON BUS_ROUTE_NO         BUS_ROUTE_NM  STND_BSST_ID BSST_ARS_NO  \
# 0       202212         4312  4312번(개포동~가락1동주민센터)     122000001       23101
# 1       202210          345     345번(송파차고지~구반포역)     122000001       23101
# 2       202210          472         472번(개포동~신촌)     122000001       23101
# 3       202206          472         472번(개포동~신촌)     122000001       23101
# 4       202210          143         143번(정릉~개포동)     122000001       23101
# ...        ...          ...                  ...           ...         ...
# 26114   202212       강남06-1   강남06-1(세곡리엔파크~수서역)     122900074       23995
# 26115   202210       강남06-1   강남06-1(세곡리엔파크~수서역)     122900074       23995
# 26116   202203       강남06-1   강남06-1(세곡리엔파크~수서역)     122900074       23995
# 26117   202202       강남06-1   강남06-1(세곡리엔파크~수서역)     122900074       23995
# 26118   202207       강남06-2   강남06-2(세곡리엔파크~수서역)     122900074       23995
#
# ...

# %%
# GBD = GBD.drop(columns=['WORK_DT'])
GBD
# Out:
#        USE_MON BUS_ROUTE_NO         BUS_ROUTE_NM  STND_BSST_ID BSST_ARS_NO  \
# 0       202212         4312  4312번(개포동~가락1동주민센터)     122000001       23101
# 1       202210          345     345번(송파차고지~구반포역)     122000001       23101
# 2       202210          472         472번(개포동~신촌)     122000001       23101
# 3       202206          472         472번(개포동~신촌)     122000001       23101
# 4       202210          143         143번(정릉~개포동)     122000001       23101
# ...        ...          ...                  ...           ...         ...
# 26114   202212       강남06-1   강남06-1(세곡리엔파크~수서역)     122900074       23995
# 26115   202210       강남06-1   강남06-1(세곡리엔파크~수서역)     122900074       23995
# 26116   202203       강남06-1   강남06-1(세곡리엔파크~수서역)     122900074       23995
# 26117   202202       강남06-1   강남06-1(세곡리엔파크~수서역)     122900074       23995
# 26118   202207       강남06-2   강남06-2(세곡리엔파크~수서역)     122900074       23995
#
# ...

# %%
# 주어진 컬럼 이름 목록과 대응하는 새로운 컬럼 이름 딕셔너리
column_mapping = {
    'USE_MON': '기준 월',
    'BUS_ROUTE_NO': '노선 번호',
    'BUS_ROUTE_NM': '노선명',
    'STND_BSST_ID': '표준버스정류장ID',
    'BSST_ARS_NO': '버스정류장ARS번호',
    'BUS_STA_NM': '정류장 이름',
    'MIDNIGHT_RIDE_NUM': '00시승차총승객수',
    'MIDNIGHT_ALIGHT_NUM': '00시하차총승객수',
    'ONE_RIDE_NUM': '01시승차총승객수',
    'ONE_ALIGHT_NUM': '01시하차총승객수',
    'TWO_RIDE_NUM': '02시승차총승객수',
    'TWO_ALIGHT_NUM': '02시하차총승객수',
    'THREE_RIDE_NUM': '03시승차총승객수',
    'THREE_ALIGHT_NUM': '03시하차총승객수',
    'FOUR_RIDE_NUM': '04시승차총승객수',
    'FOUR_ALIGHT_NUM': '04시하차총승객수',
    'FIVE_RIDE_NUM': '05시승차총승객수',
    'FIVE_ALIGHT_NUM': '05시하차총승객수',
    'SIX_RIDE_NUM': '06시승차총승객수',
    'SIX_ALIGHT_NUM': '06시하차총승객수',
    'SEVEN_RIDE_NUM': '07시승차총승객수',
    'SEVEN_ALIGHT_NUM': '07시하차총승객수',
    'EIGHT_RIDE_NUM': '08시승차총승객수M',
    'EIGHT_ALIGHT_NUM': '08시하차총승객수',
    'NINE_RIDE_NUM': '09시승차총승객수',
    'NINE_ALIGHT_NUM': '09시하차총승객수',
    'TEN_RIDE_NUM': '10시승차총승객수',
    'TEN_ALIGHT_NUM': '10시하차총승객수',
    'ELEVEN_RIDE_NUM': '11시승차총승객수',
    'ELEVEN_ALIGHT_NUM': '11시하차총승객수',
    'TWELVE_RIDE_NUM': '12시승차총승객수',
    'TWELVE_ALIGHT_NUM': '12시하차총승객수',
    'THIRTEEN_RIDE_NUM': '13시승차총승객수',
    'THIRTEEN_ALIGHT_NUM': '13시하차총승객수',
    'FOURTEEN_RIDE_NUM': '14시승차총승객수',
    'FOURTEEN_ALIGHT_NUM': '14시하차총승객수',
    'FIFTEEN_RIDE_NUM': '15시승차총승객수',
    'FIFTEEN_ALIGHT_NUM': '15시하차총승객수',
    'SIXTEEN_RIDE_NUM': '16시승차총승객수',
    'SIXTEEN_ALIGHT_NUM': '16시하차총승객수',
    'SEVENTEEN_RIDE_NUM': '17시승차총승객수',
    'SEVENTEEN_ALIGHT_NUM': '17시하차총승객수',
    'EIGHTEEN_RIDE_NUM': '18시승차총승객수',
    'EIGHTEEN_ALIGHT_NUM': '18시하차총승객수',
    'NINETEEN_RIDE_NUM': '19시승차총승객수',
    'NINETEEN_ALIGHT_NUM': '19시하차총승객수',
    'TWENTY_RIDE_NUM': '20시승차총승객수',
    'TWENTY_ALIGHT_NUM': '20시하차총승객수',
    'TWENTY_ONE_RIDE_NUM': '21시승차총승객수',
    'TWENTY_ONE_ALIGHT_NUM': '21시하차총승객수',
    'TWENTY_TWO_RIDE_NUM': '22시승차총승객수',
    'TWENTY_TWO_ALIGHT_NUM': '22시하차총승객수',
    'TWENTY_THREE_RIDE_NUM': '23시승차총승객수',
    'TWENTY_THREE_ALIGHT_NUM': '23시하차총승객수',
    'MNTN_TYP_CD': '교통수단타입코드',
    'MNTN_TYP_NM': '교통수단타입명'
}

# 컬럼 이름 변경
GBD.rename(columns=column_mapping, inplace=True)
GBD
# Out:
#          기준 월   노선 번호                  노선명  표준버스정류장ID 버스정류장ARS번호  \
# 0      202212    4312  4312번(개포동~가락1동주민센터)  122000001      23101
# 1      202210     345     345번(송파차고지~구반포역)  122000001      23101
# 2      202210     472         472번(개포동~신촌)  122000001      23101
# 3      202206     472         472번(개포동~신촌)  122000001      23101
# 4      202210     143         143번(정릉~개포동)  122000001      23101
# ...       ...     ...                  ...        ...        ...
# 26114  202212  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074      23995
# 26115  202210  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074      23995
# 26116  202203  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074      23995
# 26117  202202  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074      23995
# 26118  202207  강남06-2   강남06-2(세곡리엔파크~수서역)  122900074      23995
#
#                        정류장 이름  00시승차총승객수  00시하차총승객수  01시승차총승객수  01시하차총승객수  \
# 0                신사중학교(00020)        0.0        0.0        0.0        0.0
# ...

# %%
GBD.rename(columns={'버스정류장ARS번호': 'ARS-ID'}, inplace=True)
GBD
# Out:
#          기준 월   노선 번호                  노선명  표준버스정류장ID ARS-ID  \
# 0      202212    4312  4312번(개포동~가락1동주민센터)  122000001  23101
# 1      202210     345     345번(송파차고지~구반포역)  122000001  23101
# 2      202210     472         472번(개포동~신촌)  122000001  23101
# 3      202206     472         472번(개포동~신촌)  122000001  23101
# 4      202210     143         143번(정릉~개포동)  122000001  23101
# ...       ...     ...                  ...        ...    ...
# 26114  202212  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074  23995
# 26115  202210  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074  23995
# 26116  202203  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074  23995
# 26117  202202  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074  23995
# 26118  202207  강남06-2   강남06-2(세곡리엔파크~수서역)  122900074  23995
#
#                        정류장 이름  00시승차총승객수  00시하차총승객수  01시승차총승객수  01시하차총승객수  \
# 0                신사중학교(00020)        0.0        0.0        0.0        0.0
# 1                신사중학교(00052)      127.0       66.0        0.0        0.0
# ...

# %%
temp_df = GBD.merge(GBI, on='ARS-ID', how='left')
temp_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 temp_df = GBD.merge(GBI, on='ARS-ID', how='left')
#       2 temp_df
#
# File ~\Downloads\Project_1\venv\lib\site-packages\pandas\core\frame.py:10490, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10471 @Substitution("")
#   10472 @Appender(_merge_doc, indents=2)
#   10473 def merge(
#    (...)
#   10486     validate: MergeValidate | None = None,
#   10487 ) -> DataFrame:
#   10488     from pandas.core.reshape.merge import merge
# > 10490     return merge(
#   10491         self,
#   10492         right,
#   10493         how=how,
#   10494         on=on,
#   10495         left_on=left_on,
#   10496         right_on=right_on,
#   10497         left_index=left_index,
#   10498         right_index=right_index,
# ...

# %%
print(GBD['ARS-ID'].dtype)
print(GBI['ARS-ID'].dtype)
# Out:
# object
# int64

# %%
GBD['ARS-ID'] = GBD['ARS-ID'].astype(int)
print(GBD['ARS-ID'].dtype)
print(GBI['ARS-ID'].dtype)
# Out:
# int32
# int64

# %%
temp_df = GBD.merge(GBI, on='ARS-ID', how='left')
temp_df
# Out:
#          기준 월   노선 번호                  노선명  표준버스정류장ID  ARS-ID  \
# 0      202212    4312  4312번(개포동~가락1동주민센터)  122000001   23101
# 1      202210     345     345번(송파차고지~구반포역)  122000001   23101
# 2      202210     472         472번(개포동~신촌)  122000001   23101
# 3      202206     472         472번(개포동~신촌)  122000001   23101
# 4      202210     143         143번(정릉~개포동)  122000001   23101
# ...       ...     ...                  ...        ...     ...
# 26114  202212  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074   23995
# 26115  202210  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074   23995
# 26116  202203  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074   23995
# 26117  202202  강남06-1   강남06-1(세곡리엔파크~수서역)  122900074   23995
# 26118  202207  강남06-2   강남06-2(세곡리엔파크~수서역)  122900074   23995
#
#                        정류장 이름  00시승차총승객수  00시하차총승객수  01시승차총승객수  01시하차총승객수  \
# 0                신사중학교(00020)        0.0        0.0        0.0        0.0
# ...

# %%
temp_df.sort_values(by=['ARS-ID', '기준 월'], inplace=True)
temp_df.reset_index(drop=True, inplace=True)
temp_df
# Out:
#          기준 월   노선 번호                   노선명  표준버스정류장ID  ARS-ID  \
# 0      202201     362     362번(송파공영차고지~여의도)  122000001   23101
# 1      202201     240  240번(중랑공영차고지~신사역사거리)  122000001   23101
# 2      202201    4318  4318번(사당동출발.사당동~풍납동)  122000001   23101
# 3      202201     472          472번(개포동~신촌)  122000001   23101
# 4      202201    4318  4318번(풍납동출발.풍납동~사당동)  122000001   23101
# ...       ...     ...                   ...        ...     ...
# 26114  202211  강남06-1    강남06-1(세곡리엔파크~수서역)  122900074   23995
# 26115  202212  강남06-2    강남06-2(세곡리엔파크~수서역)  122900074   23995
# 26116  202212  강남06-2    강남06-2(세곡리엔파크~수서역)  122900074   23995
# 26117  202212  강남06-1    강남06-1(세곡리엔파크~수서역)  122900074   23995
# 26118  202212  강남06-1    강남06-1(세곡리엔파크~수서역)  122900074   23995
#
#                        정류장 이름  00시승차총승객수  00시하차총승객수  01시승차총승객수  01시하차총승객수  \
# 0                       신사중학교       35.0       47.0        6.0       12.0
# ...

# %%
# CSV 파일로 저장
# temp_df.to_csv('temp_data_bus.csv', index=False)

# %%
temp_df[(temp_df['X좌표'] == 0) | temp_df['X좌표'].isnull()]
# Out:
#          기준 월 노선 번호                    노선명  표준버스정류장ID  ARS-ID          정류장 이름  \
# 15437  202201   143           143번(정릉~개포동)  122000233   23337         개포주공1단지
# 15438  202202   143           143번(정릉~개포동)  122000233   23337         개포주공1단지
# 15439  202203   143           143번(정릉~개포동)  122000233   23337         개포주공1단지
# 15440  202204   143           143번(정릉~개포동)  122000233   23337         개포주공1단지
# 15441  202205   143           143번(정릉~개포동)  122000233   23337         개포주공1단지
# 15442  202206   143           143번(정릉~개포동)  122000233   23337         개포주공1단지
# 15443  202207   143           143번(정릉~개포동)  122000233   23337         개포주공1단지
# 15444  202208   143           143번(정릉~개포동)  122000233   23337  개포주공1단지(00056)
# 15445  202209   143           143번(정릉~개포동)  122000233   23337  개포주공1단지(00056)
# 15446  202210   143           143번(정릉~개포동)  122000233   23337  개포주공1단지(00056)
# 24954  202201  1156  1156번(퇴계원쌍용예가아파트~석계역)  222000628   23771         1156번종점
# ...
