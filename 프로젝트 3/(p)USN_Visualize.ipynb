# %% [markdown]
# # 한글

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

plt.rc("font", family="NanumGothic") # 라이브러리 불러오기와 함께 한번만 실행
from sklearn.preprocessing import MinMaxScaler, StandardScaler

plt.plot([1, 2, 3])
plt.title("한글")
plt.show()

# %%
data = {
    '울산항': 0.143032,
    '광양항': 0.123489,
    '인천항': 0.110807,
    '부산항': 0.018844
}

# 각 값을 100을 곱해서 소수점 한자리로 표현
data_percentage = {city: round(value * 100, 1) for city, value in data.items()}

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

plt.figure(figsize=(9, 7))  # 그래프 사이즈 설정

locations = list(data_percentage.keys())
values = list(data_percentage.values())

plt.bar(locations, values)
plt.xlabel('지역')
plt.ylabel('평균 대기율(%)')

# 막대에 값 표시
for i, value in enumerate(values):
    plt.text(i, value, f'{value}%', ha='center', va='bottom')

plt.show()

# %%
import pandas as pd

df = pd.read_csv('data/2022_울산_전처리_ver3.csv')

# %%
df.head()
# Out:
#    항명    호출부호      선박명  입항횟수_연도  입항횟수_횟수  구분  입출    총톤수              입항일시  \
# 0  울산  936013  해바다201호   2010.0      1.0  최종  출항     11  2010-11-10 06:00
# 1  울산  814441  에스엠103호   2012.0      1.0  최종  출항  19.77  2012-04-28 19:00
# 2  울산  070157    골든씨2호   2012.0      1.0  최종  출항     24  2012-11-17 09:00
# 3  울산  134802  해바다206호   2012.0      1.0  최종  출항     10  2012-12-25 06:00
# 4  울산  144808   케이101호   2014.0      1.0  최종  출항    151  2014-07-20 12:10
#
#                출항일시              수리일시 항해구분 계선장소_코드  계선장소_숫자  계선장소명      선박용도  \
# 0  2022-03-28 05:55  2022-04-20 16:29   기타     MLJ        1  장생포호안       기타선
# 1  2022-10-14 10:31  2022-11-29 16:35   기타     MLJ        1  장생포호안       기타선
# 2  2022-10-21 15:13  2022-11-01 14:11   기타     MLJ        1  장생포호안  석유제품 운반선
# 3  2022-03-28 05:55  2022-08-10 11:16   기타     MLJ        1  장생포호안       기타선
# 4  2022-09-28 05:40  2022-11-01 16:35   기타     MBM        1   매암부두  이.접안용 예선
#
#        순번  시설사용횟수   신고톤수 지정시설_코드  지정시설_번호  지정시설명           지정일시(FROM)  \
# 0  2632.0     1.0   11.0     MLJ      1.0  장생포호안  2010-11-10 06:00:00
# 1  4197.0     1.0   19.0     MLJ      1.0  장생포호안  2012-04-08 19:00:00
# 2   111.0     1.0   24.0     MLJ      1.0  장생포호안  2012-11-17 09:00:00
# 3  2738.0     1.0   10.0     MLJ      1.0  장생포호안  2012-12-25 00:00:00
# 4   153.0     1.0  151.0     MBM      1.0   매암부두  2014-07-20 12:10:00
#
#               지정일시(TO) 사용목적명        예보일시  허가유무          접안_대기시간 출항_대기시간  \
# 0  2022-03-28 05:55:00    기타  2022-04-20  허가완료  0 days 00:00:00     NaN
# 1  2022-10-14 10:31:00    기타  2022-11-29  허가완료  0 days 00:00:00     NaN
# 2  2022-10-21 15:13:00    기타  2022-11-01  허가완료  0 days 00:00:00     NaN
# 3  2022-03-28 05:00:00    기타  2022-04-21  허가완료  0 days 00:00:00     NaN
# 4  2022-09-28 05:40:00    기타  2022-11-01  허가완료  0 days 00:00:00     NaN
#
#       Service_Time_End Anchor   Service_Time_Start        Service_Time  \
# 0  2022-03-28 05:55:00    NaN  2010-11-10 06:00:00  4155 days 23:55:00
# 1  2022-10-14 10:31:00    NaN  2012-04-28 19:00:00  3820 days 15:31:00
# 2  2022-10-21 15:13:00    NaN  2012-11-17 09:00:00  3625 days 06:13:00
# 3  2022-03-28 05:55:00    NaN  2012-12-25 06:00:00  3379 days 23:55:00
# 4  2022-09-28 05:40:00    NaN  2014-07-20 12:10:00  2991 days 17:30:00
#
#    접안_대기시간_NumDays  Service_Time_NumDays  접안_대기시간_일  접안_대기시간_시간  접안_대기시간_분  \
# 0                0                  4155          0           0          0
# 1                0                  3820          0           0          0
# 2                0                  3625          0           0          0
# 3                0                  3379          0           0          0
# 4                0                  2991          0           0          0
#
#    Service_Time_일  Service_Time_시간  Service_Time_분  대기율
# 0            4155               23         5984635  0.0
# 1            3820               15         5501731  0.0
# 2            3625                6         5220373  0.0
# 3            3379               23         4867195  0.0
# 4            2991               17         4308090  0.0

# %%
# 각 선박용도 별 입항횟수

# %%
df['선박용도'].value_counts()
# Out:
# 선박용도
# 석유제품 운반선       29389
# 케미칼 운반선         6987
# LPG 운반선         1886
# 일반화물선           1525
# 견인용예선           1467
# 풀컨테이너선          1256
# 기타 유조선          1210
# 자동차운반선          1050
# 원유운반선           1038
# 산물선(벌크선)         826
# 급유선              725
# 기타 예선            714
# 시멘트운반선           198
# 케미칼가스 운반선        177
# 기타선              150
# 압항 예선             85
# 모래운반선             82
# 신조선               79
# 이.접안용 예선          69
# 철강재 운반선           41
# 폐기물 운반선           41
# 관공선               33
# LNG 운반선           19
# 세미(혼재)컨테이너선       14
# 코일전용선             14
# 용달선               12
# 군함                 6
# 여객선                6
# 유람선                1
# 원양 어선              1
# 냉동.냉장선             1
# 수상레저기구             1
# Name: count, dtype: int64

# %%
temp = df[['선박용도','입항횟수_횟수']].sort_values(by = '입항횟수_횟수', ascending = False)

# %%
temp['입항횟수_횟수'].sum()
# Out:
# 1211455.0

# %%
temp['방문횟수_비율'] = temp['입항횟수_횟수'] / 1211455 * 100

# %%
temp = temp.groupby(['선박용도']).sum().reset_index()

# %%
temp = temp.sort_values(by = '방문횟수_비율', ascending = False)

# %%
tp = temp[['선박용도','방문횟수_비율']]

# %%
tp
# Out:
#            선박용도    방문횟수_비율
# 12     석유제품 운반선  79.363988
# 27      케미칼 운반선   6.624101
# 7        기타 유조선   3.863123
# 2         견인용예선   2.449451
# 1       LPG 운반선   1.585944
# 5           급유선   1.447020
# 6         기타 예선   1.187993
# 31       풀컨테이너선   0.987655
# 21        원유운반선   0.658712
# 24        일반화물선   0.597216
# 28    케미칼가스 운반선   0.221304
# 10        모래운반선   0.217342
# 25       자동차운반선   0.185314
# 15       시멘트운반선   0.133476
# 23     이.접안용 예선   0.114573
# 17        압항 예선   0.095918
# 11     산물선(벌크선)   0.091790
# 8           기타선   0.078005
# 30      폐기물 운반선   0.042841
# 26      철강재 운반선   0.022535
# 29        코일전용선   0.008667
# 16          신조선   0.006521
# 3           관공선   0.005283
# 19          용달선   0.003302
# 4            군함   0.002476
# 13  세미(혼재)컨테이너선   0.001981
# 0       LNG 운반선   0.001733
# 18          여객선   0.001403
# 22          유람선   0.000083
# 20        원양 어선   0.000083
# 14       수상레저기구   0.000083
# 9        냉동.냉장선   0.000083

# %%
# 데이터프레임을 '선박용도' 열을 기준으로 정렬합니다.
temp = temp.sort_values(by='방문횟수_비율', ascending=False)

# '선박용도_순번'이라는 새로운 열을 만들어 해당 항목에 번호를 부여합니다 (1부터 시작).
temp['순위'] = [idx + 1 for idx, _ in enumerate(temp['선박용도'])]

# 결과 출력
tp = temp[['순위','선박용도',  '방문횟수_비율']]

# %%
import matplotlib.pyplot as plt

# 데이터 정렬 (위에서부터 아래로)
tp_sorted = tp.sort_values('방문횟수_비율', ascending=True).tail(10)

# 그래프 생성
plt.figure(figsize=(8, 6))  # 그래프 크기 설정

# 수평 막대 그래프 생성
bars = plt.barh(tp_sorted['선박용도'], tp_sorted['방문횟수_비율'])

# 데이터 레이블 표시
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f"{bar.get_width():.1f}",
             va='center', ha='left', color='black')

# 레이블 및 제목 설정
plt.xlabel('방문횟수_비율')
plt.title('선박용도별 상위 10개 방문횟수 비율')

# 그래프 출력
plt.show()

# %% [markdown]
# # 액체화물 / 그외 로 구분하면 어떨까 !
# 액체화물 = 석유제품 운반선, 케미칼 운반선, 기타 유조선, LPG 운반선, 원유운반선, 케미칼가스 운반선, LNG 운반선
# 기준?

# %%
Fil_df = df[df['선박용도'].isin(['석유제품 운반선', '케미칼 운반선', '기타 유조선', 'LPG 운반선', '원유운반선', '케미칼가스 운반선', 'LNG 운반선'])]

# 결과를 출력합니다.
Fil_df.info()

# 49000 >>> 40700
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40706 entries, 2 to 49101
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   항명                    40706 non-null  object
#  1   호출부호                  40706 non-null  object
#  2   선박명                   40706 non-null  object
#  3   입항횟수_연도               40706 non-null  float64
#  4   입항횟수_횟수               40706 non-null  float64
#  5   구분                    40706 non-null  object
#  6   입출                    40706 non-null  object
#  7   총톤수                   40706 non-null  object
#  8   입항일시                  40706 non-null  object
#  9   출항일시                  40706 non-null  object
#  10  수리일시                  40703 non-null  object
#  11  항해구분                  40706 non-null  object
#  12  계선장소_코드               40706 non-null  object
#  13  계선장소_숫자               40706 non-null  int64
#  14  계선장소명                 40706 non-null  object
#  15  선박용도                  40706 non-null  object
#  16  순번                    40377 non-null  float64
#  17  시설사용횟수                40377 non-null  float64
#  18  신고톤수                  40377 non-null  object
#  19  지정시설_코드               40377 non-null  object
#  20  지정시설_번호               40377 non-null  float64
#  21  지정시설명                 40377 non-null  object
#  22  지정일시(FROM)            40377 non-null  object
#  23  지정일시(TO)              40376 non-null  object
#  24  사용목적명                 40377 non-null  object
#  25  예보일시                  40377 non-null  object
#  26  허가유무                  40377 non-null  object
#  27  접안_대기시간               40706 non-null  object
#  28  출항_대기시간               838 non-null    object
#  29  Service_Time_End      40706 non-null  object
#  30  Anchor                5944 non-null   object
#  31  Service_Time_Start    40706 non-null  object
#  32  Service_Time          40706 non-null  object
#  33  접안_대기시간_NumDays       40706 non-null  int64
#  34  Service_Time_NumDays  40706 non-null  int64
#  35  접안_대기시간_일             40706 non-null  int64
#  36  접안_대기시간_시간            40706 non-null  int64
#  37  접안_대기시간_분             40706 non-null  int64
#  38  Service_Time_일        40706 non-null  int64
#  39  Service_Time_시간       40706 non-null  int64
#  40  Service_Time_분        40706 non-null  int64
#  41  대기율                   40706 non-null  float64
# dtypes: float64(6), int64(9), object(27)
# memory usage: 13.4+ MB

# %% [markdown]
# # 액체 비액체의 대기율 차이?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 조건에 따라 데이터 분리
condition = df['선박용도'].isin(['석유제품 운반선', '케미칼 운반선', '기타 유조선', 'LPG 운반선', '원유운반선', '케미칼가스 운반선', 'LNG 운반선'])
selected_rows = df[condition]
non_selected_rows = df[~condition]

# 각각의 평균 계산
selected_mean = selected_rows['대기율'].mean()
non_selected_mean = non_selected_rows['대기율'].mean()

# 시각화
plt.figure(figsize=(8, 6))
sns.barplot(x=['액체', 'Non_액체'], y=[selected_mean, non_selected_mean])
plt.title('대기율 비교')
plt.ylabel('대기율')
plt.show()

# %%
# 선박용도별 대기율의 평균 계산
ship_WR = df.groupby('선박용도')['대기율'].mean().reset_index()
ship_WR.sort_values(by='대기율', ascending=False)
# Out:
#            선박용도       대기율
# 18          여객선  0.823289
# 27      케미칼 운반선  0.217162
# 11     산물선(벌크선)  0.209274
# 1       LPG 운반선  0.200694
# 24        일반화물선  0.182060
# 12     석유제품 운반선  0.150120
# 21        원유운반선  0.147801
# 28    케미칼가스 운반선  0.119293
# 13  세미(혼재)컨테이너선  0.093597
# 10        모래운반선  0.081233
# 26      철강재 운반선  0.053670
# 16          신조선  0.038276
# 5           급유선  0.028467
# 7        기타 유조선  0.026003
# 25       자동차운반선  0.014924
# 31       풀컨테이너선  0.002964
# 8           기타선  0.002481
# 2         견인용예선  0.000400
# 15       시멘트운반선  0.000000
# 17        압항 예선  0.000000
# 14       수상레저기구  0.000000
# 19          용달선  0.000000
# 20        원양 어선  0.000000
# 9        냉동.냉장선  0.000000
# 22          유람선  0.000000
# 23     이.접안용 예선  0.000000
# 6         기타 예선  0.000000
# 4            군함  0.000000
# 3           관공선  0.000000
# 29        코일전용선  0.000000
# 30      폐기물 운반선  0.000000
# 0       LNG 운반선  0.000000

# %%
# 시각화
plt.figure(figsize=(20, 10))
ax = sns.barplot(x='선박용도', y='대기율', data=ship_WR)
plt.title('Average Air Rates by Ship Category')
plt.xticks(rotation=45, ha='right')  # X 축 라벨을 45도 기울임
plt.ylabel('Average Air Rate')

# 각 막대 위에 수치 표시
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()
